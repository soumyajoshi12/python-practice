# %%
#OLD MACDONALD: Write a function that capitalizes the first and fourth letters of a name
def old_macdonald(name):
    length=len(name)
    if(length<4):
        return name.capitalize()
    else:
        return name[0].upper()+name[1:3]+name[3].upper()+name[4:]

# %%
old_macdonald("soumya")
# Out:
# 'SouMya'

# %%
#MASTER YODA: Given a sentence, return a sentence with the words reversed
def master_yoda(sentence):
    mylist = sentence.split()
    reversed_list = mylist.reverse()
    result = "".join(reversed_list)
    return result

# %%
master_yoda("My name is soumya")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 master_yoda("My name is soumya")
#
# Cell In[26], line 4, in master_yoda(sentence)
#       2 def master_yoda(sentence):
#       3     mylist = sentence.split()
# ----> 4     result = "".join(mylist.reverse())
#       5     return result
#
# TypeError: can only join an iterable
